# %%
import pandas as pd

import plotly.express as px

df = pd.read_csv('../enaho_2023.csv', encoding='latin-1', sep=None, engine='python')

fig_hist = px.histogram(df, x="edad", title="Prueba de histograma de edades")
fig_hist.show()
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# Cell In[1], line 8
#
#       5 df = pd.read_csv('../enaho_2023.csv', encoding='latin-1', sep=None, engine='python')
#
#       7 fig_hist = px.histogram(df, x="edad", title="Prueba de histograma de edades")
#
# ----> 8 fig_hist.show()
#
#
#
# File ~\Documents\proyecto-sprint-7\application\Lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#
#    3387 """
#
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#
#    3389 specified by the renderer argument
#
#    (...)
#
#    3416 None
#
#    3417 """
#
#    3418 import plotly.io as pio
#
# -> 3420 return pio.show(self, *args, **kwargs)
#
#
#
# File ~\Documents\proyecto-sprint-7\application\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#
#     410     raise ValueError(
#
# ...
